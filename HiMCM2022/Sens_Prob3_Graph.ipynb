# %%
'''
This is the code of sensitivity analysis of the number of plants to lambda
Used in: HiMCM Problem 3
'''

# %%
import matplotlib.pyplot
import matplotlib.pyplot as plt
import numpy as np
x = [i for i in range(0, 150)]
y = [0, 1, 2, 2, 3, 4, 5, 5, 6, 6, 6, 6, 7, 8, 9, 9, 10, 10, 10, 10, 10, 13, 13, 13, 13, 13, 14, 16, 16, 16, 18, 18, 18, 18, 18, 18, 18, 18, 18, 20, 20, 20, 20, 20, 22, 22, 22, 22, 22, 22, 22, 24, 24, 24, 26, 26, 26, 26, 27, 27, 27, 27, 27, 28, 29, 29, 32, 32, 32, 32, 32, 32, 32, 32, 32, 36, 36, 36, 38, 38, 42, 42, 42, 42, 42, 42, 44, 44, 44, 44, 44, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 49, 50, 51, 51, 51, 51, 51, 56, 56, 56, 56, 56, 56, 56, 56, 56, 56, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64]
plt.figure(figsize=(8,6), dpi=300)
plt.plot(x, y, color='#00B2C5', linewidth = 2)
# plt.scatter(x,y, color = '#00B2C5', marker='x')
plt.xlabel('Number of Plants', fontsize = 14)
plt.ylabel('λ', fontsize = 14)

plt.xticks(np.linspace(0, 150, 11, endpoint=True), fontsize = 10)
plt.yticks(np.linspace(0, 65, 14, endpoint=True), fontsize = 10)

plt.title('Sensitive Analysis', fontsize = 18)

# plt.legend(loc = 'lower right', shadow = True, fancybox='blue')
plt.grid()
plt.savefig('sens_ana_3.jpg', dpi=300)

plt.show()
